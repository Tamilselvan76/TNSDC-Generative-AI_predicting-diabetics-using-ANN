# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamilselvan76/TNSDC-Generative-AI_predicting-diabetics-using-ANN/blob/main/diabetes_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('/content/archive (3).zip')

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
sns.countplot(x=dataset['Outcome'])
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
sns.boxplot(x=dataset['Outcome'],y=dataset['Pregnancies'])
# Out:
# <Axes: xlabel='Outcome', ylabel='Pregnancies'>

# %%
sns.boxplot(x=dataset['Outcome'],y=dataset['BMI'],palette='Set2')
# Out:
# <ipython-input-8-64b1ae40a44a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=dataset['Outcome'],y=dataset['BMI'],palette='Set2')
# <Axes: xlabel='Outcome', ylabel='BMI'>

# %%
sns.boxplot(x=dataset['Outcome'],y=dataset['Age'],palette='Set1')
# Out:
# <ipython-input-9-719b08f82701>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=dataset['Outcome'],y=dataset['Age'],palette='Set1')
# <Axes: xlabel='Outcome', ylabel='Age'>

# %%
sns.boxplot(x=dataset['Outcome'],y=dataset['BloodPressure'],palette='Set1')
# Out:
# <ipython-input-10-77bf681d81be>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=dataset['Outcome'],y=dataset['BloodPressure'],palette='Set1')
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %%
sns.boxplot(x=dataset['Outcome'],y=dataset['Glucose'],palette='Set2')
# Out:
# <ipython-input-11-766faab2cddc>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=dataset['Outcome'],y=dataset['Glucose'],palette='Set2')
# <Axes: xlabel='Outcome', ylabel='Glucose'>

# %%
sns.boxplot(x=dataset['Outcome'],y=dataset['SkinThickness'],palette='Set3')
# Out:
# <ipython-input-12-97e267aabd06>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=dataset['Outcome'],y=dataset['SkinThickness'],palette='Set3')
# <Axes: xlabel='Outcome', ylabel='SkinThickness'>

# %%
fig=plt.subplots(figsize=(12,6))
sns.heatmap(dataset.isnull(),cmap='viridis',yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
X=dataset.drop('Outcome',axis=1)
y=dataset['Outcome']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
X_train=Scaler.fit_transform(X_train)
X_test=Scaler.transform(X_test)
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
model=Sequential()
model.add(Dense(units=4,kernel_initializer='uniform',activation='relu',input_dim=8))
model.add(Dropout(0.2))
model.add(Dense(units=4,kernel_initializer='uniform',activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=4,kernel_initializer='uniform',activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,batch_size=20,epochs=400)
# Out:
# Epoch 1/400
# 27/27 [==============================] - 1s 2ms/step - loss: 0.6915 - accuracy: 0.6387
# Epoch 2/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.6592
# Epoch 3/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.6592
# Epoch 4/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6818 - accuracy: 0.6592
# Epoch 5/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.6592
# Epoch 6/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6762 - accuracy: 0.6592
# Epoch 7/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.6592
# Epoch 8/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6716 - accuracy: 0.6592
# Epoch 9/400
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6692 - accuracy: 0.6592
# Epoch 10/400
# ...

# %%
predictions=model.predict(X_test)
predictions=(predictions>0.5)
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print('Confusion Matrix \n',confusion_matrix(y_test,predictions))
# Out:
# 8/8 [==============================] - 0s 2ms/step
# Confusion Matrix
#  [[146   0]
#  [ 85   0]]

# %%
print('Classification Report \n',classification_report(y_test,predictions))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.63      1.00      0.77       146
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.63       231
#    macro avg       0.32      0.50      0.39       231
# weighted avg       0.40      0.63      0.49       231
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print('Accuracy of our mode when applied on test set-',accuracy_score(y_test,predictions))
# Out:
# Accuracy of our mode when applied on test set- 0.6320346320346321
